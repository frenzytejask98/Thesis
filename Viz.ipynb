# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SI0 = pd.read_csv("si_in_inv0.csv")
SI1 = pd.read_csv("si_in_inv1.csv")
SI2 = pd.read_csv("si_in_inv2.csv")
SI3 = pd.read_csv("si_in_inv3.csv")
SI4 = pd.read_csv("si_in_inv4.csv")
SI5 = pd.read_csv("si_in_inv5.csv")
SI6 = pd.read_csv("si_in_inv6.csv")
SI7 = pd.read_csv("si_in_inv7.csv")
SI8 = pd.read_csv("si_in_inv8.csv")
SI9 = pd.read_csv("si_in_inv9.csv")

ISP0 = pd.read_csv("isp_total_returns0.csv")
ISP1 = pd.read_csv("isp_total_returns1.csv")
ISP2 = pd.read_csv("isp_total_returns2.csv")
ISP3 = pd.read_csv("isp_total_returns3.csv")

City = pd.read_csv("city_total_returns.csv")

# SI0 = pd.read_csv("si_in_inv_un0.csv")
# SI1 = pd.read_csv("si_in_inv_un1.csv")
# SI2 = pd.read_csv("si_in_inv_un2.csv")
# SI3 = pd.read_csv("si_in_inv_un3.csv")
# SI4 = pd.read_csv("si_in_inv_un4.csv")
# SI5 = pd.read_csv("si_in_inv_un5.csv")
# SI6 = pd.read_csv("si_in_inv_un6.csv")
# SI7 = pd.read_csv("si_in_inv_un7.csv")
# SI8 = pd.read_csv("si_in_inv_un8.csv")
# SI9 = pd.read_csv("si_in_inv_un9.csv")

# ISP0 = pd.read_csv("isp_total_returns_un0.csv")
# ISP1 = pd.read_csv("isp_total_returns_un1.csv")
# ISP2 = pd.read_csv("isp_total_returns_un2.csv")
# ISP3 = pd.read_csv("isp_total_returns_un3.csv")

# City = pd.read_csv("city_total_returns_un.csv")

# %%
SI1.head()
# Out:
#    Unnamed: 0  total_returns  total_mMTC_services_SI  total_URLLC_services_SI  \
# 0           0        194.176                    85.9                    77.34
# 1           1        228.968                    95.1                    95.62
# 2           2        233.944                   103.8                    92.96
# 3           3        281.200                   137.7                   102.50
# 4           4        368.160                   170.2                   141.40
#
#    number_of_active_consumers
# 0                          32
# 1                          32
# 2                          28
# 3                          31
# 4                          32

# %%
ISP1.head()
# Out:
#    Unnamed: 0  total_returns  total_mMTC_services_ISP  \
# 0           0       597.3520                    378.2
# 1           1       648.2000                    408.0
# 2           2       780.9648                    498.6
# 3           3       871.5560                    602.9
# 4           4       987.3640                    694.0
#
#    total_URLLC_services_ISP
# 0                    339.40
# 1                    370.00
# 2                    440.76
# 3                    458.70
# 4                    511.80

# %%
City.head()
# Out:
#    Unnamed: 0  total_returns  total_mMTC_services_City  \
# 0           0     185.965248                     949.7
# 1           1     194.376000                     996.6
# 2           2     243.366144                    1262.1
# 3           3     262.909920                    1502.1
# 4           4     302.914080                    1738.8
#
#    total_URLLC_services_City
# 0                     902.98
# 1                     941.00
# 2                    1167.94
# 3                    1162.70
# 4                    1333.80

# %%
# figure=plt.figure(figsize = (10, 10))
figure, axis = plt.subplots(2, 5, figsize=(28,10))

axis[0,0].plot(SI0["Unnamed: 0"],SI0["total_returns"])
axis[0,0].set_xlabel("Years")
axis[0,0].set_ylabel("Returns")

axis[0,1].plot(SI1["Unnamed: 0"],SI1["total_returns"])
axis[0,1].set_xlabel("Years")
axis[0,1].set_ylabel("Returns")

axis[0,2].plot(SI2["Unnamed: 0"],SI2["total_returns"])
axis[0,2].set_xlabel("Years")
axis[0,2].set_ylabel("Returns")

axis[0,3].plot(SI3["Unnamed: 0"],SI3["total_returns"])
axis[0,3].set_xlabel("Years")
axis[0,3].set_ylabel("Returns")

axis[0,4].plot(SI4["Unnamed: 0"],SI4["total_returns"])
axis[0,4].set_xlabel("Years")
axis[0,4].set_ylabel("Returns")

axis[1,0].plot(SI5["Unnamed: 0"],SI5["total_returns"])
axis[1,0].set_xlabel("Years")
axis[1,0].set_ylabel("Returns")

axis[1,1].plot(SI6["Unnamed: 0"],SI6["total_returns"])
axis[1,1].set_xlabel("Years")
axis[1,1].set_ylabel("Returns")

axis[1,2].plot(SI7["Unnamed: 0"],SI7["total_returns"])
axis[1,2].set_xlabel("Years")
axis[1,2].set_ylabel("Returns")

axis[1,3].plot(SI8["Unnamed: 0"],SI8["total_returns"])
axis[1,3].set_xlabel("Years")
axis[1,3].set_ylabel("Returns")

axis[1,4].plot(SI9["Unnamed: 0"],SI9["total_returns"])
axis[1,4].set_xlabel("Years")
axis[1,4].set_ylabel("Returns")

# plt.title("X vs Y")
plt.show()


# figure.savefig("output_all_si_adopt.jpg")
figure.savefig("un_output_all_si_adopt.jpg")

# %%
figure, axis = plt.subplots(2, 5, figsize=(28,10))
# figure.tight_layout()
axis[0,0].plot(SI0["Unnamed: 0"],SI0["total_mMTC_services_SI"], label="mMTC service usage")
axis[0,0].set_xlabel("Years")
axis[0,0].set_ylabel("Units of service")

axis[0,1].plot(SI1["Unnamed: 0"],SI1["total_mMTC_services_SI"])
axis[0,1].set_xlabel("Years")
axis[0,1].set_ylabel("Units of service")

axis[0,2].plot(SI2["Unnamed: 0"],SI2["total_mMTC_services_SI"])
axis[0,2].set_xlabel("Years")
axis[0,2].set_ylabel("Units of service")

axis[0,3].plot(SI3["Unnamed: 0"],SI3["total_mMTC_services_SI"])
axis[0,3].set_xlabel("Years")
axis[0,3].set_ylabel("Units of service")

axis[0,4].plot(SI4["Unnamed: 0"],SI4["total_mMTC_services_SI"])
axis[0,4].set_xlabel("Years")
axis[0,4].set_ylabel("Units of service")

axis[1,0].plot(SI5["Unnamed: 0"],SI5["total_mMTC_services_SI"])
axis[1,0].set_xlabel("Years")
axis[1,0].set_ylabel("Units of service")

axis[1,1].plot(SI6["Unnamed: 0"],SI6["total_mMTC_services_SI"])
axis[1,1].set_xlabel("Years")
axis[1,1].set_ylabel("Units of service")

axis[1,2].plot(SI7["Unnamed: 0"],SI7["total_mMTC_services_SI"])
axis[1,2].set_xlabel("Years")
axis[1,2].set_ylabel("Units of service")

axis[1,3].plot(SI8["Unnamed: 0"],SI8["total_mMTC_services_SI"])
axis[1,3].set_xlabel("Years")
axis[1,3].set_ylabel("Units of service")

axis[1,4].plot(SI9["Unnamed: 0"],SI9["total_mMTC_services_SI"])
axis[1,4].set_xlabel("Years")
axis[1,4].set_ylabel("Units of service")

axis[0,0].plot(SI0["Unnamed: 0"],SI0["total_URLLC_services_SI"], label="URLLC service usage")

axis[0,1].plot(SI1["Unnamed: 0"],SI1["total_URLLC_services_SI"])

axis[0,2].plot(SI2["Unnamed: 0"],SI2["total_URLLC_services_SI"])

axis[0,3].plot(SI3["Unnamed: 0"],SI3["total_URLLC_services_SI"])

axis[0,4].plot(SI4["Unnamed: 0"],SI4["total_URLLC_services_SI"])

axis[1,0].plot(SI5["Unnamed: 0"],SI5["total_URLLC_services_SI"])

axis[1,1].plot(SI6["Unnamed: 0"],SI6["total_URLLC_services_SI"])

axis[1,2].plot(SI7["Unnamed: 0"],SI7["total_URLLC_services_SI"])

axis[1,3].plot(SI8["Unnamed: 0"],SI8["total_URLLC_services_SI"])

axis[1,4].plot(SI9["Unnamed: 0"],SI9["total_URLLC_services_SI"])
# plt.title("X vs Y")
axis[0,0].legend(fontsize=12)
plt.show()


figure.savefig("un_output_all_si_adopt_mmtc_urllc.jpg")

# %%
plt.figure(figsize = (20, 10))

figure1, axis = plt.subplots(2, 2)
figure1.tight_layout()

axis[0,0].plot(ISP0["Unnamed: 0"],ISP0["total_returns"])
axis[0,0].set_xlabel("Years")
axis[0,0].set_ylabel("Returns")

axis[1,0].plot(ISP1["Unnamed: 0"],ISP1["total_returns"])
axis[1,0].set_xlabel("Years")
axis[1,0].set_ylabel("Returns")

axis[0,1].plot(ISP2["Unnamed: 0"],ISP2["total_returns"])
axis[0,1].set_xlabel("Years")
axis[0,1].set_ylabel("Returns")

axis[1,1].plot(ISP3["Unnamed: 0"],ISP3["total_returns"])
axis[1,1].set_xlabel("Years")
axis[1,1].set_ylabel("Returns")

# plt.title("X vs Y")
plt.show()
figure1.savefig("un_output_all_isp_adopt.jpg")

# plt.savefig("output.png")

# %%
plt.figure(figsize = (15, 7.5))

figure1, axis = plt.subplots(2, 2)
figure1.tight_layout()
axis[0,0].plot(ISP0["Unnamed: 0"],ISP0["total_mMTC_services_ISP"], label="mMTC service usage")
axis[0,0].set_xlabel("Years")
axis[0,0].set_ylabel("Units of service")

axis[1,0].plot(ISP1["Unnamed: 0"],ISP1["total_mMTC_services_ISP"])
axis[1,0].set_xlabel("Years")
axis[1,0].set_ylabel("Units of service")

axis[0,1].plot(ISP2["Unnamed: 0"],ISP2["total_mMTC_services_ISP"])
axis[0,1].set_xlabel("Years")
axis[0,1].set_ylabel("Units of service")

axis[1,1].plot(ISP3["Unnamed: 0"],ISP3["total_mMTC_services_ISP"])
axis[1,1].set_xlabel("Years")
axis[1,1].set_ylabel("Units of service")

axis[0,0].plot(ISP0["Unnamed: 0"],ISP0["total_URLLC_services_ISP"], label="URLLC service usage")

axis[1,0].plot(ISP1["Unnamed: 0"],ISP1["total_URLLC_services_ISP"])

axis[0,1].plot(ISP2["Unnamed: 0"],ISP2["total_URLLC_services_ISP"])

axis[1,1].plot(ISP3["Unnamed: 0"],ISP3["total_URLLC_services_ISP"])
# plt.title("X vs Y")
axis[0,0].legend(fontsize=12)
plt.show()
figure1.savefig("un_output_all_isp_adopt_mmtc_urllc.jpg")

# plt.savefig("output.png")

# %%
# plt.figure(figsize = (10, 5))
# plt.plot(ISP1["Unnamed: 0"],ISP1["total_mMTC_services_ISP"])
# plt.xlabel("Years")
# plt.ylabel("Returns")
# # plt.title("X vs Y")
# plt.show()

# %%
# plt.figure(figsize = (10, 5))
# plt.plot(ISP1["Unnamed: 0"],ISP1["total_URLLC_services_ISP"])
# plt.xlabel("Years")
# plt.ylabel("Returns")
# plt.title("X vs Y")
# plt.show()

# %%
fig = plt.figure(figsize = (10, 5))
plt.plot(City["Unnamed: 0"], City["total_returns"])
plt.xlabel("Years")
plt.ylabel("Returns")
# plt.title("X vs Y")
plt.show()

fig.savefig("un_output_city_adopt.jpg")

# %%
fig2 = plt.figure(figsize = (10, 5))
plt.plot(City["Unnamed: 0"], City["total_mMTC_services_City"], label="mMTC services")
plt.plot(City["Unnamed: 0"], City["total_URLLC_services_City"], label="URLLC services")
plt.xlabel("Years")
plt.ylabel("Returns")
plt.legend(fontsize=12)
# plt.title("X vs Y")
plt.show()
fig2.savefig("un_output_city_URLLC_mMTC_adopt.jpg")

# %%
# number_of_active_consumers
fig4, axis = plt.subplots(2, 5, figsize=(25,8))
fig4.tight_layout()

axis[0,0].plot(SI0["Unnamed: 0"],SI0["number_of_active_consumers"])
axis[0,0].set_xlabel("Years")
axis[0,0].set_ylabel("No. of Active Consumers")

axis[0,1].plot(SI1["Unnamed: 0"],SI1["number_of_active_consumers"])
axis[0,1].set_xlabel("Years")
axis[0,1].set_ylabel("No. of Active Consumers")

axis[0,2].plot(SI2["Unnamed: 0"],SI2["number_of_active_consumers"])
axis[0,2].set_xlabel("Years")
axis[0,2].set_ylabel("No. of Active Consumers")

axis[0,3].plot(SI3["Unnamed: 0"],SI3["number_of_active_consumers"])
axis[0,3].set_xlabel("Years")
axis[0,3].set_ylabel("No. of Active Consumers")

axis[0,4].plot(SI4["Unnamed: 0"],SI4["number_of_active_consumers"])
axis[0,4].set_xlabel("Years")
axis[0,4].set_ylabel("No. of Active Consumers")

axis[1,0].plot(SI5["Unnamed: 0"],SI5["number_of_active_consumers"])
axis[1,0].set_xlabel("Years")
axis[1,0].set_ylabel("No. of Active Consumers")

axis[1,1].plot(SI6["Unnamed: 0"],SI6["number_of_active_consumers"])
axis[1,1].set_xlabel("Years")
axis[1,1].set_ylabel("No. of Active Consumers")

axis[1,2].plot(SI7["Unnamed: 0"],SI7["number_of_active_consumers"])
axis[1,2].set_xlabel("Years")
axis[1,2].set_ylabel("No. of Active Consumers")

axis[1,3].plot(SI8["Unnamed: 0"],SI8["number_of_active_consumers"])
axis[1,3].set_xlabel("Years")
axis[1,3].set_ylabel("No. of Active Consumers")

axis[1,4].plot(SI9["Unnamed: 0"],SI9["number_of_active_consumers"])
axis[1,4].set_xlabel("Years")
axis[1,4].set_ylabel("No. of Active Consumers")

# plt.title("X vs Y")
# plt.show()
axis[0,0].legend(fontsize=12)
# plt.title("X vs Y")
plt.show()
fig4.savefig("output_SI_number_of_active_consumers_adopt.jpg")
# Out:
# No handles with labels found to put in legend.
