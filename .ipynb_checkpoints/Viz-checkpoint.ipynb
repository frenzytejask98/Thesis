# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
SI0 = pd.read_csv("si_in_inv0.csv")
SI1 = pd.read_csv("si_in_inv1.csv")
SI2 = pd.read_csv("si_in_inv2.csv")
SI3 = pd.read_csv("si_in_inv3.csv")
SI4 = pd.read_csv("si_in_inv4.csv")
SI5 = pd.read_csv("si_in_inv5.csv")
SI6 = pd.read_csv("si_in_inv6.csv")
SI7 = pd.read_csv("si_in_inv7.csv")
SI8 = pd.read_csv("si_in_inv8.csv")
SI9 = pd.read_csv("si_in_inv9.csv")

ISP0 = pd.read_csv("isp_total_returns0.csv")
ISP1 = pd.read_csv("isp_total_returns1.csv")
ISP2 = pd.read_csv("isp_total_returns2.csv")
ISP3 = pd.read_csv("isp_total_returns3.csv")

City = pd.read_csv("city_total_returns.csv")

# %%
SI1.head()
# Out:
#    Unnamed: 0  total_returns  total_mMTC_services_SI  total_URLLC_services_SI  \
# 0           0     148.669588               64.518040                64.731960
# 1           1     174.297893               79.840355                72.659645
# 2           2     206.037779               97.540737                83.459263
# 3           3     191.198465               92.838449                75.661551
# 4           4     196.382365               98.308782                75.441218
#
#    number_of_active_consumers
# 0                          29
# 1                          30
# 2                          30
# 3                          23
# 4                          21

# %%
ISP1.head()
# Out:
#    Unnamed: 0  total_returns  total_mMTC_services_ISP  \
# 0           0     677.138533               278.954889
# 1           1     740.175692               315.831026
# 2           2     858.744049               389.686502
# 3           3     940.028740               435.070868
# 4           4     936.901931               444.410230
#
#    total_URLLC_services_ISP
# 0                306.295111
# 1                326.418974
# 2                360.813498
# 3                388.429132
# 4                378.839770

# %%
City.head()
# Out:
#    Unnamed: 0  total_returns  total_mMTC_services_ISP  \
# 0           0    1592.161721               667.377596
# 1           1    1806.861279               763.129071
# 2           2    2130.337817               967.540609
# 3           3    2320.447671              1094.341098
# 4           4    2388.931139              1120.646204
#
#    total_URLLC_services_ISP
# 0                711.372404
# 1                802.870929
# 2                894.459391
# 3                943.158902
# 4                975.603796

# %%
figure, axis = plt.subplots(5, 2)

axis[0,0].plot(SI0["Unnamed: 0"],SI0["total_returns"])

axis[1,0].plot(SI1["Unnamed: 0"],SI1["total_returns"])

axis[2,0].plot(SI2["Unnamed: 0"],SI2["total_returns"])

axis[3,0].plot(SI3["Unnamed: 0"],SI3["total_returns"])

axis[4,0].plot(SI4["Unnamed: 0"],SI4["total_returns"])

axis[0,1].plot(SI5["Unnamed: 0"],SI5["total_returns"])

axis[1,1].plot(SI6["Unnamed: 0"],SI6["total_returns"])

axis[2,1].plot(SI7["Unnamed: 0"],SI7["total_returns"])

axis[3,1].plot(SI8["Unnamed: 0"],SI8["total_returns"])

axis[4,1].plot(SI9["Unnamed: 0"],SI9["total_returns"])


# plt.title("X vs Y")
plt.show()


# plt.savefig("output.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-958d941ce9ad> in <module>
#      11 axis[4,0].plot(SI4["Unnamed: 0"],SI4["total_returns"])
#      12
# ---> 13 axis[0,1].plot(SI5["Unnamed: 0"],S5["total_returns"])
#      14
#      15 axis[1,1].plot(SI6["Unnamed: 0"],SI6["total_returns"])
#
# NameError: name 'S5' is not defined

# %%
# plt.figure(figsize = (10, 5))

figure, axis = plt.subplots(2, 2)

plt.plot(ISP0["Unnamed: 0"],ISP0["total_returns"])
plt.xlabel("Years")
plt.ylabel("Returns")

plt.plot(ISP1["Unnamed: 0"],ISP1["total_returns"])
plt.xlabel("Years")
plt.ylabel("Returns")

plt.plot(ISP2["Unnamed: 0"],ISP2["total_returns"])
plt.xlabel("Years")
plt.ylabel("Returns")

plt.plot(ISP3["Unnamed: 0"],ISP3["total_returns"])
plt.xlabel("Years")
plt.ylabel("Returns")

# plt.title("X vs Y")
plt.show()


# plt.savefig("output.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a65a44ef13b7> in <module>
#       3 figure, axis = plt.subplots(5, 2)
#       4
# ----> 5 plt.plot(ISP0["Unnamed: 0"],ISP0["total_returns"])
#       6 plt.xlabel("Years")
#       7 plt.ylabel("Returns")
#
# NameError: name 'ISP0' is not defined

# %%
plt.figure(figsize = (10, 5))
plt.plot(ISP1["Unnamed: 0"],ISP1["total_mMTC_services_ISP"])
plt.xlabel("Years")
plt.ylabel("Returns")
# plt.title("X vs Y")
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(ISP1["Unnamed: 0"],ISP1["total_URLLC_services_ISP"])
plt.xlabel("Years")
plt.ylabel("Returns")
# plt.title("X vs Y")
plt.show()

# %%
plt.figure(figsize = (10, 5))
plt.plot(City["Unnamed: 0"], City["total_returns"])
plt.xlabel("Years")
plt.ylabel("Returns")
# plt.title("X vs Y")
plt.show()
